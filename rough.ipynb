# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors

# %%
df = pd.read_csv('dataset.csv')
df.drop(columns=df.columns[0], axis=1, inplace=True)
df.drop_duplicates(['track_id'], inplace=True)
df.shape
# Out:
# (89741, 20)

# %%
# Out:
#                       track_id               artists  \
# 48807   24CA5I411NVDYodjjmKPx3  The Notorious B.I.G.
# 44172   5m9uiFH9sK5wxRZdfN62n9     Breaking Benjamin
# 79833   0uhYgQQ6WX9rCONnum7Fmw           Fiona Apple
# 38314   7KwJrAQMoJyUEBes3evMLv       The Buttertones
# 107233  53PlbcGzLTx65vjaS6tG0N        Modern Talking
#
#                                                album_name  \
# 48807   NOTORIOUS Music From and Inspired by the Origi...
# 44172   Shallow Bay: The Best Of Breaking Benjamin (Ex...
# 79833                                    When The Pawn...
# 38314                                         Buttertones
# 107233                                  Ready For Romance
#
#                                    track_name  popularity  duration_ms  \
# 48807        Kick in the Door - 2008 Remaster          59       214546
# 44172                       The Diary Of Jane          59       200213
# 79833                                  I Know          59       295133
# 38314             Orpheus Under the Influence          59       134080
# 107233  Atlantis Is Calling (S.O.S. for Love)          59       230000
#
#         explicit  danceability  energy  key  loudness  mode  speechiness  \
# 48807       True         0.721   0.918   10    -5.125     0       0.4550
# 44172      False         0.390   0.958   10    -4.455     0       0.0622
# 79833      False         0.324   0.211    0   -14.223     1       0.0287
# 38314      False         0.362   0.871    2    -6.546     1       0.0502
# 107233     False         0.707   0.640    3   -11.674     0       0.0371
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 48807       0.045900          0.000000    0.1560    0.795  179.726
# 44172       0.000057          0.043700    0.1210    0.348  167.045
# 79833       0.944000          0.003100    0.1180    0.199  146.367
# 38314       0.036500          0.000256    0.1140    0.526  151.722
# 107233      0.214000          0.000247    0.0624    0.731  113.448
#
#         time_signature track_genre
# 48807                4    hardcore
# 44172                4      grunge
# 79833                3       piano
# 38314                4      garage
# 107233               4   synth-pop

# %%
df.head()
# Out:
#                  track_id                 artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# 3  Can't Help Falling In Love          71       201933     False
# 4                     Hold On          82       198853     False
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.676  0.4610    1    -6.746     0       0.1430        0.0322
# 1         0.420  0.1660    1   -17.235     1       0.0763        0.9240
# 2         0.438  0.3590    0    -9.734     1       0.0557        0.2100
# 3         0.266  0.0596    0   -18.515     1       0.0363        0.9050
# 4         0.618  0.4430    2    -9.681     1       0.0526        0.4690
#
#    instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0          0.000001    0.3580    0.715   87.917               4    acoustic
# 1          0.000006    0.1010    0.267   77.489               4    acoustic
# 2          0.000000    0.1170    0.120   76.332               4    acoustic
# 3          0.000071    0.1320    0.143  181.740               3    acoustic
# 4          0.000000    0.0829    0.167  119.949               4    acoustic

# %%
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
selected_features = ['danceability', 'energy', 'loudness', 'speechiness',
                     'acousticness', 'instrumentalness', 'liveness', 'valence']
X = df[selected_features]
X_normalized = (X - X.mean()) / X.std()

# %%
df[selected_features]
# Out:
#         danceability  energy  loudness  speechiness  acousticness  \
# 0              0.676  0.4610    -6.746       0.1430        0.0322
# 1              0.420  0.1660   -17.235       0.0763        0.9240
# 2              0.438  0.3590    -9.734       0.0557        0.2100
# 3              0.266  0.0596   -18.515       0.0363        0.9050
# 4              0.618  0.4430    -9.681       0.0526        0.4690
# ...              ...     ...       ...          ...           ...
# 113995         0.172  0.2350   -16.393       0.0422        0.6400
# 113996         0.174  0.1170   -18.318       0.0401        0.9940
# 113997         0.629  0.3290   -10.895       0.0420        0.8670
# 113998         0.587  0.5060   -10.889       0.0297        0.3810
# 113999         0.526  0.4870   -10.204       0.0725        0.6810
#
#         instrumentalness  liveness  valence
# 0               0.000001    0.3580   0.7150
# 1               0.000006    0.1010   0.2670
# 2               0.000000    0.1170   0.1200
# 3               0.000071    0.1320   0.1430
# 4               0.000000    0.0829   0.1670
# ...                  ...       ...      ...
# 113995          0.928000    0.0863   0.0339
# 113996          0.976000    0.1050   0.0350
# 113997          0.000000    0.0839   0.7430
# 113998          0.000000    0.2700   0.4130
# 113999          0.000000    0.0893   0.7080
#
# [89741 rows x 8 columns]

# %%
knn_model = NearestNeighbors(n_neighbors=11, algorithm='brute', metric='euclidean')
knn_model.fit(X_normalized)
# Out:
# NearestNeighbors(algorithm='brute', metric='euclidean', n_neighbors=11)

# %%
def recommend_songs(features):
    normalized_features = (features - X.mean()) / X.std()
    _, indices = knn_model.kneighbors([normalized_features])
    recommended_songs = df.iloc[indices[0]]
    return recommended_songs

# %%
example_features = [0.676,0.4610,-6.746,0.1430,	0.0322,	0.000001,0.3580,0.7150]
recommended_songs = recommend_songs(example_features)
recommended_songs
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
#                       track_id      artists                  album_name  \
# 0       5SuOikwiRyPMVoIQDJUgSV  Gen Hoshino                      Comedy
# 67860   2snbAel9GoxA6i6iH0Wvw9        Ozuna                    OzuTochi
# 111951  6aBFjYfhZrgJtxiKaip1BH     Gramatik      Beatz & Pieces, Vol. 1
# 18213   5DPHLBx7WCVwKBe0eTNp5V  Aunty Donna                   The Album
# 32700   7KAQwDyAcdiHZhQU01KLkN      TroyBoi               Left Is Right
# 357     3IORLAm07yxo4T7B8cRET3   Jason Mraz           Look For The Good
# 39173   54XZSt4qoPwUh0s9q0A7oA       Trille                   Blink 182
# 63905   007t1Fel5tcxHOEfSYWuGM          MFÖ                      Ve MFÖ
# 89881   4v7riPZWyAclrOfUSwD0zp       Camilo        De Adentro Pa Afuera
# 99464   34evGV6SaoRLHTcXXUVOpb          Jax                    90s Kids
# 9690    5upbYedO0GhVf7wOMcj2Lk       Maneva  Tudo Vira Reggae (Ao Vivo)
#
#                                 track_name  popularity  duration_ms  explicit  \
# 0                                   Comedy          73       230666     False
# 67860                            Te Pienso          66       147760     False
# 111951                            Skylight          45       226333     False
# 18213                       Fuccboi Anthem          25       202300      True
# 32700                                  ili          24       245000     False
# 357     Look For The Good (Single Version)          21       239697     False
# 39173                            Blink 182          53       160076      True
# 63905                       Bu Aşk Olur Mu          33       198243     False
# 89881                           Aeropuerto          78       177626     False
# 99464                             90s Kids          64       163815      True
# 9690                      Morena - Ao Vivo          44       215424     False
#
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0              0.676   0.461    1    -6.746     0        0.143       0.03220
# 67860          0.668   0.533    2    -7.409     1        0.098       0.11700
# 111951         0.667   0.608    0    -6.071     1        0.110       0.09830
# 18213          0.697   0.642    2    -7.038     1        0.161       0.09150
# 32700          0.634   0.588    9    -6.753     1        0.106       0.05750
# 357            0.710   0.615    0    -8.230     1        0.133       0.03840
# 39173          0.730   0.629   10    -7.507     1        0.142       0.00976
# 63905          0.693   0.613    4    -6.304     0        0.114       0.14200
# 89881          0.690   0.580    0    -4.395     1        0.199       0.03280
# 99464          0.714   0.657    0    -6.436     1        0.118       0.08020
# 9690           0.655   0.512   11    -7.429     0        0.188       0.05060
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 0               0.000001     0.358    0.715   87.917               4
# 67860           0.000000     0.305    0.676  163.733               4
# 111951          0.001860     0.336    0.684   90.045               4
# 18213           0.000000     0.333    0.768  159.899               5
# 32700           0.002310     0.441    0.770  174.006               4
# 357             0.000000     0.283    0.746   90.263               4
# 39173           0.050700     0.358    0.631   91.498               4
# 63905           0.000000     0.295    0.764   71.967               4
# 89881           0.000000     0.328    0.708  197.635               4
# 99464           0.000000     0.350    0.725  151.898               4
# 9690            0.000177     0.318    0.539  160.101               4
#
#               track_genre
# 0                acoustic
# 67860               latin
# 111951           trip-hop
# 18213              comedy
# 32700          electronic
# 357              acoustic
# 39173              german
# 63905              j-rock
# 89881           reggaeton
# 99464   singer-songwriter
# 9690               brazil
